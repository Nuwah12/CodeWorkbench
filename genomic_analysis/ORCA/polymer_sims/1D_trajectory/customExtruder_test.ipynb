# %%
from extruder import Extruder
import numpy as np
import seaborn as sns
import h5py

# %% [markdown]
# ### Translocating and writing trajectories using custom extruder class

# %%
N = 500
occupied = np.zeros(N)
occupied[0] = 1
occupied[-1] = 1
steps = 200
steps_occupation = []
LEFNum = 2
num_chunks = 50

### Blockers (i.e. CTCF) - {pos. : prob.}
left_blockers_capture = {100:0.9}
right_blockers_capture = {300:0.9}
left_blockers_release = {100:0.02}
right_blockers_release = {300:0.02}



e1 = Extruder(leg1 = 175,
             leg2 = 175+1,
             ebf1 = False,
             left_blockers_capture = left_blockers_capture,
             right_blockers_capture = right_blockers_capture,
             left_blockers_release = left_blockers_release,
             right_blockers_release = right_blockers_release,
             extrusion_occupancy = occupied,
             lifetime = 10e7)
e2 = Extruder(leg1 = 250,
             leg2 = 250+1,
             ebf1 = False,
             left_blockers_capture = left_blockers_capture,
             right_blockers_capture = right_blockers_capture,
             left_blockers_release = left_blockers_release,
             right_blockers_release = right_blockers_release,
             extrusion_occupancy = occupied,
             lifetime = 10e7)
outf = "trajectory/LEFPositions.h5"
with h5py.File(outf, mode='w') as f:
    dset = f.create_dataset("positions", 
            shape=(steps, LEFNum, 2), 
            dtype=np.int32, 
            compression="gzip")
    bins = np.linspace(0, steps, num_chunks, dtype=int)
    for st,end in zip(bins[:-1], bins[1:]):
        cur = []
        for i in range(st,end):
            occupied = e1.translocate(occupied)
            occupied = e2.translocate(occupied)
            positions = [(extruder.leg1.pos, extruder.leg2.pos) for extruder in [e1,e2]]
            cur.append(positions)
        cur = np.array(cur)
        dset[st:end] = np.array(cur)
    f.attrs["N"] = N
    f.attrs["LEFNum"] = LEFNum
# Out:
# Leg 175: captured = False
# Leg at 175 translocating
# Leg 176: captured = False
# Leg at 176 translocating
# Leg 250: captured = False
# Leg at 250 translocating
# Leg 251: captured = False
# Leg at 251 translocating
# Leg 174: captured = False
# Leg at 174 translocating
# Leg 177: captured = False
# Leg at 177 translocating
# Leg 249: captured = False
# Leg at 249 translocating
# Leg 252: captured = False
# Leg at 252 translocating
# Leg 173: captured = False
# Leg at 173 translocating
# Leg 178: captured = False
# Leg at 178 translocating
# Leg 248: captured = False
# Leg at 248 translocating
# Leg 253: captured = False
# Leg at 253 translocating
# Leg 172: captured = False
# Leg at 172 translocating
# Leg 179: captured = False
# Leg at 179 translocating
# Leg 247: captured = False
# Leg at 247 translocating
# Leg 254: captured = False
# Leg at 254 translocating
# Leg 171: captured = False
# Leg at 171 translocating
# Leg 180: captured = False
# Leg at 180 translocating
# Leg 246: captured = False
# Leg at 246 translocating
# Leg 255: captured = False
# Leg at 255 translocating
# Leg 170: captured = False
# Leg at 170 translocating
# Leg 181: captured = False
# Leg at 181 translocating
# Leg 245: captured = False
# Leg at 245 translocating
# Leg 256: captured = False
# Leg at 256 translocating
# Leg 169: captured = False
# Leg at 169 translocating
# Leg 182: captured = False
# Leg at 182 translocating
# Leg 244: captured = False
# Leg at 244 translocating
# Leg 257: captured = False
# Leg at 257 translocating
# Leg 168: captured = False
# Leg at 168 translocating
# Leg 183: captured = False
# Leg at 183 translocating
# Leg 243: captured = False
# Leg at 243 translocating
# Leg 258: captured = False
# Leg at 258 translocating
# Leg 167: captured = False
# Leg at 167 translocating
# Leg 184: captured = False
# Leg at 184 translocating
# Leg 242: captured = False
# Leg at 242 translocating
# Leg 259: captured = False
# Leg at 259 translocating
# Leg 166: captured = False
# Leg at 166 translocating
# Leg 185: captured = False
# Leg at 185 translocating
# Leg 241: captured = False
# Leg at 241 translocating
# Leg 260: captured = False
# Leg at 260 translocating
# Leg 165: captured = False
# Leg at 165 translocating
# Leg 186: captured = False
# Leg at 186 translocating
# Leg 240: captured = False
# Leg at 240 translocating
# Leg 261: captured = False
# Leg at 261 translocating
# Leg 164: captured = False
# Leg at 164 translocating
# Leg 187: captured = False
# Leg at 187 translocating
# Leg 239: captured = False
# Leg at 239 translocating
# Leg 262: captured = False
# Leg at 262 translocating
# Leg 163: captured = False
# Leg at 163 translocating
# Leg 188: captured = False
# Leg at 188 translocating
# Leg 238: captured = False
# Leg at 238 translocating
# Leg 263: captured = False
# Leg at 263 translocating
# Leg 162: captured = False
# Leg at 162 translocating
# Leg 189: captured = False
# Leg at 189 translocating
# Leg 237: captured = False
# Leg at 237 translocating
# Leg 264: captured = False
# Leg at 264 translocating
# Leg 161: captured = False
# Leg at 161 translocating
# Leg 190: captured = False
# Leg at 190 translocating
# Leg 236: captured = False
# Leg at 236 translocating
# Leg 265: captured = False
# Leg at 265 translocating
# Leg 160: captured = False
# Leg at 160 translocating
# Leg 191: captured = False
# Leg at 191 translocating
# Leg 235: captured = False
# Leg at 235 translocating
# Leg 266: captured = False
# Leg at 266 translocating
# Leg 159: captured = False
# Leg at 159 translocating
# Leg 192: captured = False
# Leg at 192 translocating
# Leg 234: captured = False
# Leg at 234 translocating
# Leg 267: captured = False
# Leg at 267 translocating
# Leg 158: captured = False
# Leg at 158 translocating
# Leg 193: captured = False
# Leg at 193 translocating
# Leg 233: captured = False
# Leg at 233 translocating
# Leg 268: captured = False
# Leg at 268 translocating
# Leg 157: captured = False
# Leg at 157 translocating
# Leg 194: captured = False
# Leg at 194 translocating
# Leg 232: captured = False
# Leg at 232 translocating
# Leg 269: captured = False
# Leg at 269 translocating
# Leg 156: captured = False
# Leg at 156 translocating
# Leg 195: captured = False
# Leg at 195 translocating
# Leg 231: captured = False
# Leg at 231 translocating
# Leg 270: captured = False
# Leg at 270 translocating
# Leg 155: captured = False
# Leg at 155 translocating
# Leg 196: captured = False
# Leg at 196 translocating
# Leg 230: captured = False
# Leg at 230 translocating
# Leg 271: captured = False
# Leg at 271 translocating
# Leg 154: captured = False
# Leg at 154 translocating
# Leg 197: captured = False
# Leg at 197 translocating
# Leg 229: captured = False
# Leg at 229 translocating
# Leg 272: captured = False
# Leg at 272 translocating
# Leg 153: captured = False
# Leg at 153 translocating
# Leg 198: captured = False
# Leg at 198 translocating
# Leg 228: captured = False
# Leg at 228 translocating
# Leg 273: captured = False
# Leg at 273 translocating
# Leg 152: captured = False
# Leg at 152 translocating
# Leg 199: captured = False
# Leg at 199 translocating
# Leg 227: captured = False
# Leg at 227 translocating
# Leg 274: captured = False
# Leg at 274 translocating
# Leg 151: captured = False
# Leg at 151 translocating
# Leg 200: captured = False
# Leg at 200 translocating
# Leg 226: captured = False
# Leg at 226 translocating
# Leg 275: captured = False
# Leg at 275 translocating
# Leg 150: captured = False
# Leg at 150 translocating
# Leg 201: captured = False
# Leg at 201 translocating
# Leg 225: captured = False
# Leg at 225 translocating
# Leg 276: captured = False
# Leg at 276 translocating
# Leg 149: captured = False
# Leg at 149 translocating
# Leg 202: captured = False
# Leg at 202 translocating
# Leg 224: captured = False
# Leg at 224 translocating
# Leg 277: captured = False
# Leg at 277 translocating
# Leg 148: captured = False
# Leg at 148 translocating
# Leg 203: captured = False
# Leg at 203 translocating
# Leg 223: captured = False
# Leg at 223 translocating
# Leg 278: captured = False
# Leg at 278 translocating
# Leg 147: captured = False
# Leg at 147 translocating
# Leg 204: captured = False
# Leg at 204 translocating
# Leg 222: captured = False
# Leg at 222 translocating
# Leg 279: captured = False
# Leg at 279 translocating
# Leg 146: captured = False
# Leg at 146 translocating
# Leg 205: captured = False
# Leg at 205 translocating
# Leg 221: captured = False
# Leg at 221 translocating
# Leg 280: captured = False
# Leg at 280 translocating
# Leg 145: captured = False
# Leg at 145 translocating
# Leg 206: captured = False
# Leg at 206 translocating
# Leg 220: captured = False
# Leg at 220 translocating
# Leg 281: captured = False
# Leg at 281 translocating
# Leg 144: captured = False
# Leg at 144 translocating
# Leg 207: captured = False
# Leg at 207 translocating
# Leg 219: captured = False
# Leg at 219 translocating
# Leg 282: captured = False
# Leg at 282 translocating
# Leg 143: captured = False
# Leg at 143 translocating
# Leg 208: captured = False
# Leg at 208 translocating
# Leg 218: captured = False
# Leg at 218 translocating
# Leg 283: captured = False
# Leg at 283 translocating
# Leg 142: captured = False
# Leg at 142 translocating
# Leg 209: captured = False
# Leg at 209 translocating
# Leg 217: captured = False
# Leg at 217 translocating
# Leg 284: captured = False
# Leg at 284 translocating
# Leg 141: captured = False
# Leg at 141 translocating
# Leg 210: captured = False
# Leg at 210 translocating
# Leg 216: captured = False
# Leg at 216 translocating
# Leg 285: captured = False
# Leg at 285 translocating
# Leg 140: captured = False
# Leg at 140 translocating
# Leg 211: captured = False
# Leg at 211 translocating
# Leg 215: captured = False
# Leg at 215 translocating
# Leg 286: captured = False
# Leg at 286 translocating
# Leg 139: captured = False
# Leg at 139 translocating
# Leg 212: captured = False
# Leg at 212 translocating
# Leg 214: captured = False
# Leg -1 stalled at pos 214
# Leg 287: captured = False
# Leg at 287 translocating
# Leg 138: captured = False
# Leg at 138 translocating
# Leg 213: captured = False
# Leg 1 stalled at pos 213
# Leg 214: captured = False
# Leg -1 stalled at pos 214
# Leg 288: captured = False
# Leg at 288 translocating
# Leg 137: captured = False
# Leg at 137 translocating
# Leg 213: captured = False
# Leg 1 stalled at pos 213
# Leg 214: captured = False
# Leg -1 stalled at pos 214
# Leg 289: captured = False
# Leg at 289 translocating
# Leg 136: captured = False
# Leg at 136 translocating
# Leg 213: captured = False
# Leg 1 stalled at pos 213
# Leg 214: captured = False
# Leg -1 stalled at pos 214
# Leg 290: captured = False
# Leg at 290 translocating
# Leg 135: captured = False
# Leg at 135 translocating
# Leg 213: captured = False
# Leg 1 stalled at pos 213
# Unloading cohesin at pos 214, 291
# Leg 411: captured = False
# Leg at 411 translocating
# Leg 412: captured = False
# Leg at 412 translocating
# Leg 134: captured = False
# Leg at 134 translocating
# Leg 213: captured = False
# Leg at 213 translocating
# Leg 410: captured = False
# Leg at 410 translocating
# Leg 413: captured = False
# Leg at 413 translocating
# Leg 133: captured = False
# Leg at 133 translocating
# Leg 214: captured = False
# Leg at 214 translocating
# Leg 409: captured = False
# Leg at 409 translocating
# Leg 414: captured = False
# Leg at 414 translocating
# Leg 132: captured = False
# Leg at 132 translocating
# Leg 215: captured = False
# Leg at 215 translocating
# Leg 408: captured = False
# Leg at 408 translocating
# Leg 415: captured = False
# Leg at 415 translocating
# Leg 131: captured = False
# Leg at 131 translocating
# Leg 216: captured = False
# Leg at 216 translocating
# Leg 407: captured = False
# Leg at 407 translocating
# Leg 416: captured = False
# Leg at 416 translocating
# Leg 130: captured = False
# Leg at 130 translocating
# Leg 217: captured = False
# Leg at 217 translocating
# Leg 406: captured = False
# Leg at 406 translocating
# Leg 417: captured = False
# Leg at 417 translocating
# Leg 129: captured = False
# Leg at 129 translocating
# Leg 218: captured = False
# Leg at 218 translocating
# Leg 405: captured = False
# Leg at 405 translocating
# Leg 418: captured = False
# Leg at 418 translocating
# Leg 128: captured = False
# Leg at 128 translocating
# Leg 219: captured = False
# Leg at 219 translocating
# Leg 404: captured = False
# Leg at 404 translocating
# Leg 419: captured = False
# Leg at 419 translocating
# Leg 127: captured = False
# Leg at 127 translocating
# Leg 220: captured = False
# Leg at 220 translocating
# Leg 403: captured = False
# Leg at 403 translocating
# Leg 420: captured = False
# Leg at 420 translocating
# Leg 126: captured = False
# Leg at 126 translocating
# Leg 221: captured = False
# Leg at 221 translocating
# Leg 402: captured = False
# Leg at 402 translocating
# Leg 421: captured = False
# Leg at 421 translocating
# Leg 125: captured = False
# Leg at 125 translocating
# Leg 222: captured = False
# Leg at 222 translocating
# Leg 401: captured = False
# Leg at 401 translocating
# Leg 422: captured = False
# Leg at 422 translocating
# Leg 124: captured = False
# Leg at 124 translocating
# Leg 223: captured = False
# Leg at 223 translocating
# Leg 400: captured = False
# Leg at 400 translocating
# Leg 423: captured = False
# Leg at 423 translocating
# Leg 123: captured = False
# Leg at 123 translocating
# Leg 224: captured = False
# Leg at 224 translocating
# Leg 399: captured = False
# Leg at 399 translocating
# Leg 424: captured = False
# Leg at 424 translocating
# Leg 122: captured = False
# Leg at 122 translocating
# Leg 225: captured = False
# Leg at 225 translocating
# Leg 398: captured = False
# Leg at 398 translocating
# Leg 425: captured = False
# Leg at 425 translocating
# Leg 121: captured = False
# Leg at 121 translocating
# Leg 226: captured = False
# Leg at 226 translocating
# Leg 397: captured = False
# Leg at 397 translocating
# Leg 426: captured = False
# Leg at 426 translocating
# Leg 120: captured = False
# Leg at 120 translocating
# Leg 227: captured = False
# Leg at 227 translocating
# Leg 396: captured = False
# Leg at 396 translocating
# Leg 427: captured = False
# Leg at 427 translocating
# Leg 119: captured = False
# Leg at 119 translocating
# Leg 228: captured = False
# Leg at 228 translocating
# Leg 395: captured = False
# Leg at 395 translocating
# Leg 428: captured = False
# Leg at 428 translocating
# Leg 118: captured = False
# Leg at 118 translocating
# Leg 229: captured = False
# Leg at 229 translocating
# Leg 394: captured = False
# Leg at 394 translocating
# Leg 429: captured = False
# Leg at 429 translocating
# Leg 117: captured = False
# Leg at 117 translocating
# Leg 230: captured = False
# Leg at 230 translocating
# Leg 393: captured = False
# Leg at 393 translocating
# Leg 430: captured = False
# Leg at 430 translocating
# Leg 116: captured = False
# Leg at 116 translocating
# Leg 231: captured = False
# Leg at 231 translocating
# Leg 392: captured = False
# Leg at 392 translocating
# Leg 431: captured = False
# Leg at 431 translocating
# Leg 115: captured = False
# Leg at 115 translocating
# Leg 232: captured = False
# Leg at 232 translocating
# Leg 391: captured = False
# Leg at 391 translocating
# Leg 432: captured = False
# Leg at 432 translocating
# Leg 114: captured = False
# Leg at 114 translocating
# Leg 233: captured = False
# Leg at 233 translocating
# Leg 390: captured = False
# Leg at 390 translocating
# Leg 433: captured = False
# Leg at 433 translocating
# Leg 113: captured = False
# Leg at 113 translocating
# Leg 234: captured = False
# Leg at 234 translocating
# Leg 389: captured = False
# Leg at 389 translocating
# Leg 434: captured = False
# Leg at 434 translocating
# Leg 112: captured = False
# Leg at 112 translocating
# Leg 235: captured = False
# Leg at 235 translocating
# Leg 388: captured = False
# Leg at 388 translocating
# Leg 435: captured = False
# Leg at 435 translocating
# Leg 111: captured = False
# Leg at 111 translocating
# Leg 236: captured = False
# Leg at 236 translocating
# Leg 387: captured = False
# Leg at 387 translocating
# Leg 436: captured = False
# Leg at 436 translocating
# Leg 110: captured = False
# Leg at 110 translocating
# Leg 237: captured = False
# Leg at 237 translocating
# Leg 386: captured = False
# Leg at 386 translocating
# Leg 437: captured = False
# Leg at 437 translocating
# Leg 109: captured = False
# Leg at 109 translocating
# Leg 238: captured = False
# Leg at 238 translocating
# Leg 385: captured = False
# Leg at 385 translocating
# Leg 438: captured = False
# Leg at 438 translocating
# Leg 108: captured = False
# Leg at 108 translocating
# Leg 239: captured = False
# Leg at 239 translocating
# Leg 384: captured = False
# Leg at 384 translocating
# Leg 439: captured = False
# Leg at 439 translocating
# Leg 107: captured = False
# Leg at 107 translocating
# Leg 240: captured = False
# Leg at 240 translocating
# Leg 383: captured = False
# Leg at 383 translocating
# Leg 440: captured = False
# Leg at 440 translocating
# Leg 106: captured = False
# Leg at 106 translocating
# Leg 241: captured = False
# Leg at 241 translocating
# Leg 382: captured = False
# Leg at 382 translocating
# Leg 441: captured = False
# Leg at 441 translocating
# Leg 105: captured = False
# Leg at 105 translocating
# Leg 242: captured = False
# Leg at 242 translocating
# Leg 381: captured = False
# Leg at 381 translocating
# Leg 442: captured = False
# Leg at 442 translocating
# Leg 104: captured = False
# Leg at 104 translocating
# Leg 243: captured = False
# Leg at 243 translocating
# Leg 380: captured = False
# Leg at 380 translocating
# Leg 443: captured = False
# Leg at 443 translocating
# Leg 103: captured = False
# Leg at 103 translocating
# Leg 244: captured = False
# Leg at 244 translocating
# Leg 379: captured = False
# Leg at 379 translocating
# Leg 444: captured = False
# Leg at 444 translocating
# Leg 102: captured = False
# Leg at 102 translocating
# Leg 245: captured = False
# Leg at 245 translocating
# Leg 378: captured = False
# Leg at 378 translocating
# Leg 445: captured = False
# Leg at 445 translocating
# Leg 101: captured = False
# Leg at 101 translocating
# Leg 246: captured = False
# Leg at 246 translocating
# Leg 377: captured = False
# Leg at 377 translocating
# Leg 446: captured = False
# Leg at 446 translocating
# Leg 100: captured = True
# Leg 247: captured = False
# Leg at 247 translocating
# Leg 376: captured = False
# Leg at 376 translocating
# Leg 447: captured = False
# Leg at 447 translocating
# Leg 100: captured = True
# Leg 248: captured = False
# Leg at 248 translocating
# Leg 375: captured = False
# Leg at 375 translocating
# Leg 448: captured = False
# Leg at 448 translocating
# Leg 100: captured = True
# Leg 249: captured = False
# Leg at 249 translocating
# Leg 374: captured = False
# Leg at 374 translocating
# Leg 449: captured = False
# Leg at 449 translocating
# Leg 100: captured = True
# Leg 250: captured = False
# Leg at 250 translocating
# Leg 373: captured = False
# Leg at 373 translocating
# Leg 450: captured = False
# Leg at 450 translocating
# Leg 100: captured = True
# Leg 251: captured = False
# Leg at 251 translocating
# Leg 372: captured = False
# Leg at 372 translocating
# Leg 451: captured = False
# Leg at 451 translocating
# Leg 100: captured = True
# Leg 252: captured = False
# Leg at 252 translocating
# Leg 371: captured = False
# Leg at 371 translocating
# Leg 452: captured = False
# Leg at 452 translocating
# Leg 100: captured = True
# Leg 253: captured = False
# Leg at 253 translocating
# Leg 370: captured = False
# Leg at 370 translocating
# Leg 453: captured = False
# Leg at 453 translocating
# Leg 100: captured = True
# Leg 254: captured = False
# Leg at 254 translocating
# Leg 369: captured = False
# Leg at 369 translocating
# Leg 454: captured = False
# Leg at 454 translocating
# Leg 100: captured = True
# Leg 255: captured = False
# Leg at 255 translocating
# Leg 368: captured = False
# Leg at 368 translocating
# Leg 455: captured = False
# Leg at 455 translocating
# Leg 100: captured = True
# Leg 256: captured = False
# Leg at 256 translocating
# Leg 367: captured = False
# Leg at 367 translocating
# Leg 456: captured = False
# Leg at 456 translocating
# Leg 100: captured = True
# Leg 257: captured = False
# Leg at 257 translocating
# Leg 366: captured = False
# Leg at 366 translocating
# Leg 457: captured = False
# Leg at 457 translocating
# Leg 100: captured = True
# Leg 258: captured = False
# Leg at 258 translocating
# Leg 365: captured = False
# Leg at 365 translocating
# Leg 458: captured = False
# Leg at 458 translocating
# Leg 100: captured = True
# Leg 259: captured = False
# Leg at 259 translocating
# Leg 364: captured = False
# Leg at 364 translocating
# Leg 459: captured = False
# Leg at 459 translocating
# Leg 100: captured = True
# Leg 260: captured = False
# Leg at 260 translocating
# Leg 363: captured = False
# Leg at 363 translocating
# Leg 460: captured = False
# Leg at 460 translocating
# Leg 100: captured = True
# Leg 261: captured = False
# Leg at 261 translocating
# Leg 362: captured = False
# Leg at 362 translocating
# Leg 461: captured = False
# Leg at 461 translocating
# Leg 100: captured = True
# Leg 262: captured = False
# Leg at 262 translocating
# Leg 361: captured = False
# Leg at 361 translocating
# Leg 462: captured = False
# Leg at 462 translocating
# Leg 100: captured = True
# Leg 263: captured = False
# Leg at 263 translocating
# Leg 360: captured = False
# Leg at 360 translocating
# Leg 463: captured = False
# Leg at 463 translocating
# Leg 100: captured = True
# Leg 264: captured = False
# Leg at 264 translocating
# Leg 359: captured = False
# Leg at 359 translocating
# Leg 464: captured = False
# Leg at 464 translocating
# Leg 100: captured = True
# Leg 265: captured = False
# Leg at 265 translocating
# Leg 358: captured = False
# Leg at 358 translocating
# Leg 465: captured = False
# Leg at 465 translocating
# Leg 100: captured = True
# Leg 266: captured = False
# Leg at 266 translocating
# Leg 357: captured = False
# Leg at 357 translocating
# Leg 466: captured = False
# Leg at 466 translocating
# Leg 100: captured = True
# Leg 267: captured = False
# Leg at 267 translocating
# Leg 356: captured = False
# Leg at 356 translocating
# Leg 467: captured = False
# Leg at 467 translocating
# Leg 100: captured = True
# Leg 268: captured = False
# Leg at 268 translocating
# Leg 355: captured = False
# Leg at 355 translocating
# Leg 468: captured = False
# Leg at 468 translocating
# Leg 100: captured = True
# Leg 269: captured = False
# Leg at 269 translocating
# Leg 354: captured = False
# Leg at 354 translocating
# Leg 469: captured = False
# Leg at 469 translocating
# Leg 100: captured = True
# Leg 270: captured = False
# Leg at 270 translocating
# Leg 353: captured = False
# Leg at 353 translocating
# Leg 470: captured = False
# Leg at 470 translocating
# Leg 100: captured = True
# Leg 271: captured = False
# Leg at 271 translocating
# Leg 352: captured = False
# Leg at 352 translocating
# Leg 471: captured = False
# Leg at 471 translocating
# Leg 100: captured = True
# Leg 272: captured = False
# Leg at 272 translocating
# Leg 351: captured = False
# Leg at 351 translocating
# Leg 472: captured = False
# Leg at 472 translocating
# Leg 100: captured = True
# Leg 273: captured = False
# Leg at 273 translocating
# Leg 350: captured = False
# Leg at 350 translocating
# Leg 473: captured = False
# Leg at 473 translocating
# Leg 100: captured = True
# Leg 274: captured = False
# Leg at 274 translocating
# Leg 349: captured = False
# Leg at 349 translocating
# Leg 474: captured = False
# Leg at 474 translocating
# Leg 100: captured = True
# Leg 275: captured = False
# Leg at 275 translocating
# Leg 348: captured = False
# Leg at 348 translocating
# Leg 475: captured = False
# Leg at 475 translocating
# Leg 100: captured = True
# Leg 276: captured = False
# Leg at 276 translocating
# Leg 347: captured = False
# Leg at 347 translocating
# Leg 476: captured = False
# Leg at 476 translocating
# Leg 100: captured = True
# Leg 277: captured = False
# Leg at 277 translocating
# Leg 346: captured = False
# Leg at 346 translocating
# Leg 477: captured = False
# Leg at 477 translocating
# Leg 100: captured = True
# Leg 278: captured = False
# Leg at 278 translocating
# Leg 345: captured = False
# Leg at 345 translocating
# Leg 478: captured = False
# Leg at 478 translocating
# Leg 100: captured = True
# Leg 279: captured = False
# Leg at 279 translocating
# Leg 344: captured = False
# Leg at 344 translocating
# Leg 479: captured = False
# Leg at 479 translocating
# Leg 100: captured = True
# Leg 280: captured = False
# Leg at 280 translocating
# Leg 343: captured = False
# Leg at 343 translocating
# Leg 480: captured = False
# Leg at 480 translocating
# Leg 100: captured = True
# Leg 281: captured = False
# Leg at 281 translocating
# Leg 342: captured = False
# Leg at 342 translocating
# Leg 481: captured = False
# Leg at 481 translocating
# Leg 100: captured = True
# Leg 282: captured = False
# Leg at 282 translocating
# Leg 341: captured = False
# Leg at 341 translocating
# Leg 482: captured = False
# Leg at 482 translocating
# Leg 100: captured = True
# Leg 283: captured = False
# Leg at 283 translocating
# Leg 340: captured = False
# Leg at 340 translocating
# Leg 483: captured = False
# Leg at 483 translocating
# Leg 100: captured = True
# Leg 284: captured = False
# Leg at 284 translocating
# Leg 339: captured = False
# Leg at 339 translocating
# Leg 484: captured = False
# Leg at 484 translocating
# Leg 100: captured = True
# Leg 285: captured = False
# Leg at 285 translocating
# Leg 338: captured = False
# Leg at 338 translocating
# Leg 485: captured = False
# Leg at 485 translocating
# Leg 100: captured = True
# Leg 286: captured = False
# Leg at 286 translocating
# Leg 337: captured = False
# Leg at 337 translocating
# Leg 486: captured = False
# Leg at 486 translocating
# Leg 100: captured = True
# Leg 287: captured = False
# Leg at 287 translocating
# Leg 336: captured = False
# Leg at 336 translocating
# Leg 487: captured = False
# Leg at 487 translocating
# Leg 100: captured = True
# Leg 288: captured = False
# Leg at 288 translocating
# Leg 335: captured = False
# Leg at 335 translocating
# Leg 488: captured = False
# Leg at 488 translocating
# Leg 100: captured = True
# Leg 289: captured = False
# Leg at 289 translocating
# Leg 334: captured = False
# Leg at 334 translocating
# Leg 489: captured = False
# Leg at 489 translocating
# Leg 100: captured = True
# Leg 290: captured = False
# Leg at 290 translocating
# Leg 333: captured = False
# Leg at 333 translocating
# Leg 490: captured = False
# Leg at 490 translocating
# Leg 100: captured = True
# Leg 291: captured = False
# Leg at 291 translocating
# Leg 332: captured = False
# Leg at 332 translocating
# Leg 491: captured = False
# Leg at 491 translocating
# Leg 100: captured = True
# Leg 292: captured = False
# Leg at 292 translocating
# Leg 331: captured = False
# Leg at 331 translocating
# Leg 492: captured = False
# Leg at 492 translocating
# Leg 100: captured = True
# Leg 293: captured = False
# Leg at 293 translocating
# Leg 330: captured = False
# Leg at 330 translocating
# Leg 493: captured = False
# Leg at 493 translocating
# Leg 100: captured = True
# Leg 294: captured = False
# Leg at 294 translocating
# Leg 329: captured = False
# Leg at 329 translocating
# Leg 494: captured = False
# Leg at 494 translocating
# Leg 100: captured = True
# Leg 295: captured = False
# Leg at 295 translocating
# Leg 328: captured = False
# Leg at 328 translocating
# Leg 495: captured = False
# Leg at 495 translocating
# Leg 100: captured = True
# Leg 296: captured = False
# Leg at 296 translocating
# Leg 327: captured = False
# Leg at 327 translocating
# Leg 496: captured = False
# Leg at 496 translocating
# Leg 100: captured = True
# Leg 297: captured = False
# Leg at 297 translocating
# Leg 326: captured = False
# Leg at 326 translocating
# Leg 497: captured = False
# Leg at 497 translocating
# Leg 100: captured = True
# Leg 298: captured = False
# Leg at 298 translocating
# Leg 325: captured = False
# Leg at 325 translocating
# Leg 498: captured = False
# Leg 1 stalled at pos 498
# Leg 100: captured = True
# Leg 299: captured = False
# Leg at 299 translocating
# Leg 324: captured = False
# Leg at 324 translocating
# Leg 498: captured = False
# Leg 1 stalled at pos 498
# Leg 100: captured = True
# Leg 300: captured = True
# Leg 323: captured = False
# Leg at 323 translocating
# Leg 498: captured = False
# Leg 1 stalled at pos 498
# Leg 100: captured = True
# Leg 300: captured = True
# Leg 322: captured = False
# Leg at 322 translocating
# Leg 498: captured = False
# Leg 1 stalled at pos 498
# Leg 100: captured = True
# Leg 300: captured = True
# Leg 321: captured = False
# Leg at 321 translocating
# Leg 498: captured = False
# Leg 1 stalled at pos 498
# Leg 100: captured = True
# Leg 300: captured = True
# Leg 320: captured = False
# Leg at 320 translocating
# Leg 498: captured = False
# Leg 1 stalled at pos 498
# Leg 100: captured = True
# Leg 300: captured = True
# Leg 319: captured = False
# Leg at 319 translocating
# Leg 498: captured = False
# Leg 1 stalled at pos 498
# Leg 100: captured = True
# Leg 300: captured = True
# Leg 318: captured = False
# Leg at 318 translocating
# Leg 498: captured = False
# Leg 1 stalled at pos 498
# Leg 100: captured = True
# Leg 300: captured = True
# Leg 317: captured = False
# Leg at 317 translocating
# Leg 498: captured = False
# Leg 1 stalled at pos 498
# Leg 100: captured = True
# Leg 300: captured = True
# Leg 316: captured = False
# Leg at 316 translocating
# Leg 498: captured = False
# Leg 1 stalled at pos 498
# Leg 100: captured = True
# Leg 300: captured = True
# Leg 315: captured = False
# Leg at 315 translocating
# Leg 498: captured = False
# Leg 1 stalled at pos 498
# Leg 100: captured = True
# Leg 300: captured = True
# Leg 314: captured = False
# Leg at 314 translocating
# Leg 498: captured = False
# Leg 1 stalled at pos 498
# Leg 100: captured = True
# Leg 300: captured = True
# Leg 313: captured = False
# Leg at 313 translocating
# Leg 498: captured = False
# Leg 1 stalled at pos 498
# Leg 100: captured = True
# Leg 300: captured = True
# Leg 312: captured = False
# Leg at 312 translocating
# Leg 498: captured = False
# Leg 1 stalled at pos 498
# Leg 100: captured = True
# Leg 300: captured = True
# Leg 311: captured = False
# Leg at 311 translocating
# Leg 498: captured = False
# Leg 1 stalled at pos 498
# Leg 100: captured = True
# Leg 300: captured = True
# Leg 310: captured = False
# Leg at 310 translocating
# Leg 498: captured = False
# Leg 1 stalled at pos 498
# Leg 100: captured = True
# Leg 300: captured = True
# Leg 309: captured = False
# Leg at 309 translocating
# Leg 498: captured = False
# Leg 1 stalled at pos 498
# Leg 100: captured = True
# Leg 300: captured = True
# Leg 308: captured = False
# Leg at 308 translocating
# Leg 498: captured = False
# Leg 1 stalled at pos 498
# Leg 100: captured = True
# Leg 300: captured = True
# Leg 307: captured = False
# Leg at 307 translocating
# Leg 498: captured = False
# Leg 1 stalled at pos 498
# Leg 100: captured = True
# Leg 300: captured = True
# Unloading cohesin at pos 306, 498
# Leg 157: captured = False
# Leg at 157 translocating
# Leg 158: captured = False
# Leg at 158 translocating
# Leg 100: captured = True
# Leg 300: captured = True
# Leg 156: captured = False
# Leg at 156 translocating
# Leg 159: captured = False
# Leg at 159 translocating
# Leg 100: captured = True
# Leg 300: captured = True
# Leg 155: captured = False
# Leg at 155 translocating
# Leg 160: captured = False
# Leg at 160 translocating
# Leg 100: captured = True
# Leg 300: captured = True
# Leg 154: captured = False
# Leg at 154 translocating
# Leg 161: captured = False
# Leg at 161 translocating
# Leg 100: captured = True
# Leg 300: captured = True
# Leg 153: captured = False
# Leg at 153 translocating
# Leg 162: captured = False
# Leg at 162 translocating
# Leg 100: captured = True
# Leg 300: captured = True
# Leg 152: captured = False
# Leg at 152 translocating
# Leg 163: captured = False
# Leg at 163 translocating
# Leg 100: captured = True
# Leg 300: captured = True
# Leg 151: captured = False
# Leg at 151 translocating
# Leg 164: captured = False
# Leg at 164 translocating
# Leg 100: captured = True
# Leg 300: captured = True
# Leg 150: captured = False
# Leg at 150 translocating
# Leg 165: captured = False
# Leg at 165 translocating
# Leg 100: captured = True
# Leg 300: captured = True
# Leg 149: captured = False
# Leg at 149 translocating
# Leg 166: captured = False
# Leg at 166 translocating
# Leg 100: captured = True
# Leg 300: captured = True
# Leg 148: captured = False
# Leg at 148 translocating
# Leg 167: captured = False
# Leg at 167 translocating
# Leg 100: captured = True
# Leg 300: captured = True
# Leg 147: captured = False
# Leg at 147 translocating
# Leg 168: captured = False
# Leg at 168 translocating
# Leg 100: captured = True
# Leg 300: captured = True
# Leg 146: captured = False
# Leg at 146 translocating
# Leg 169: captured = False
# Leg at 169 translocating
# Leg -1 released at pos 100 with prob 0.005964122814555939
# Leg 100: captured = False
# Leg at 100 translocating
# Leg 300: captured = True
# Leg 145: captured = False
# Leg at 145 translocating
# Leg 170: captured = False
# Leg at 170 translocating
# Leg 99: captured = False
# Leg at 99 translocating
# Leg 300: captured = True
# Leg 144: captured = False
# Leg at 144 translocating
# Leg 171: captured = False
# Leg at 171 translocating
# Leg 98: captured = False
# Leg at 98 translocating
# Leg 300: captured = True
# Leg 143: captured = False
# Leg at 143 translocating
# Leg 172: captured = False
# Leg at 172 translocating
# Leg 97: captured = False
# Leg at 97 translocating
# Leg 300: captured = True
# Leg 142: captured = False
# Leg at 142 translocating
# Leg 173: captured = False
# Leg at 173 translocating
# Leg 96: captured = False
# Leg at 96 translocating
# Leg 300: captured = True
# Leg 141: captured = False
# Leg at 141 translocating
# Leg 174: captured = False
# Leg at 174 translocating
# Leg 95: captured = False
# Leg at 95 translocating
# Leg 300: captured = True
# Leg 140: captured = False
# Leg at 140 translocating
# Leg 175: captured = False
# Leg at 175 translocating
# Leg 94: captured = False
# Leg at 94 translocating
# Leg 300: captured = True
# Leg 139: captured = False
# Leg at 139 translocating
# Leg 176: captured = False
# Leg at 176 translocating
# Leg 93: captured = False
# Leg at 93 translocating
# Leg 300: captured = True
# Leg 138: captured = False
# Leg at 138 translocating
# Leg 177: captured = False
# Leg at 177 translocating
# Leg 92: captured = False
# Leg at 92 translocating
# Leg 300: captured = True
# Leg 137: captured = False
# Leg at 137 translocating
# Leg 178: captured = False
# Leg at 178 translocating
# Leg 91: captured = False
# Leg at 91 translocating
# Leg 300: captured = True
# Leg 136: captured = False
# Leg at 136 translocating
# Leg 179: captured = False
# Leg at 179 translocating
# Leg 90: captured = False
# Leg at 90 translocating
# Leg 300: captured = True
# Leg 135: captured = False
# Leg at 135 translocating
# Leg 180: captured = False
# Leg at 180 translocating
# Leg 89: captured = False
# Leg at 89 translocating
# Leg 300: captured = True
# Leg 134: captured = False
# Leg at 134 translocating
# Leg 181: captured = False
# Leg at 181 translocating
# Leg 88: captured = False
# Leg at 88 translocating
# Leg 300: captured = True
# Leg 133: captured = False
# Leg at 133 translocating
# Leg 182: captured = False
# Leg at 182 translocating
# Leg 87: captured = False
# Leg at 87 translocating
# Leg 300: captured = True
# Leg 132: captured = False
# Leg at 132 translocating
# Leg 183: captured = False
# Leg at 183 translocating
# Leg 86: captured = False
# Leg at 86 translocating
# Leg 300: captured = True
# Leg 131: captured = False
# Leg at 131 translocating
# Leg 184: captured = False
# Leg at 184 translocating
# Leg 85: captured = False
# Leg at 85 translocating
# Leg 300: captured = True
# Leg 130: captured = False
# Leg at 130 translocating
# Leg 185: captured = False
# Leg at 185 translocating
# Leg 84: captured = False
# Leg at 84 translocating
# Leg 300: captured = True
# Leg 129: captured = False
# Leg at 129 translocating
# Leg 186: captured = False
# Leg at 186 translocating
# Leg 83: captured = False
# Leg at 83 translocating
# Leg 300: captured = True
# Leg 128: captured = False
# Leg at 128 translocating
# Leg 187: captured = False
# Leg at 187 translocating
# Leg 82: captured = False
# Leg at 82 translocating
# Leg 300: captured = True
# Leg 127: captured = False
# Leg at 127 translocating
# Leg 188: captured = False
# Leg at 188 translocating
# Leg 81: captured = False
# Leg at 81 translocating
# Leg 300: captured = True
# Leg 126: captured = False
# Leg at 126 translocating
# Leg 189: captured = False
# Leg at 189 translocating
# Leg 1 released at pos 300 with prob 0.0042708025800849425
# Leg 80: captured = False
# Leg at 80 translocating
# Leg 300: captured = False
# Leg at 300 translocating
# Leg 125: captured = False
# Leg at 125 translocating
# Leg 190: captured = False
# Leg at 190 translocating
# Leg 79: captured = False
# Leg at 79 translocating
# Leg 301: captured = False
# Leg at 301 translocating
# Leg 124: captured = False
# Leg at 124 translocating
# Leg 191: captured = False
# Leg at 191 translocating
# Leg 78: captured = False
# Leg at 78 translocating
# Leg 302: captured = False
# Leg at 302 translocating
# Leg 123: captured = False
# Leg at 123 translocating
# Leg 192: captured = False
# Leg at 192 translocating
# Leg 77: captured = False
# Leg at 77 translocating
# Leg 303: captured = False
# Leg at 303 translocating
# Leg 122: captured = False
# Leg at 122 translocating
# Leg 193: captured = False
# Leg at 193 translocating
# Leg 76: captured = False
# Leg at 76 translocating
# Leg 304: captured = False
# Leg at 304 translocating
# Leg 121: captured = False
# Leg at 121 translocating
# Leg 194: captured = False
# Leg at 194 translocating
# Leg 75: captured = False
# Leg at 75 translocating
# Leg 305: captured = False
# Leg at 305 translocating
# Leg 120: captured = False
# Leg at 120 translocating
# Leg 195: captured = False
# Leg at 195 translocating
# Leg 74: captured = False
# Leg at 74 translocating
# Leg 306: captured = False
# Leg at 306 translocating
# Leg 119: captured = False
# Leg at 119 translocating
# Leg 196: captured = False
# Leg at 196 translocating
# Leg 73: captured = False
# Leg at 73 translocating
# Leg 307: captured = False
# Leg at 307 translocating
# Leg 118: captured = False
# Leg at 118 translocating
# Leg 197: captured = False
# Leg at 197 translocating
# Leg 72: captured = False
# Leg at 72 translocating
# Leg 308: captured = False
# Leg at 308 translocating
# Leg 117: captured = False
# Leg at 117 translocating
# Leg 198: captured = False
# Leg at 198 translocating
# Leg 71: captured = False
# Leg at 71 translocating
# Leg 309: captured = False
# Leg at 309 translocating
# Leg 116: captured = False
# Leg at 116 translocating
# Leg 199: captured = False
# Leg at 199 translocating
# Leg 70: captured = False
# Leg at 70 translocating
# Leg 310: captured = False
# Leg at 310 translocating
# Leg 115: captured = False
# Leg at 115 translocating
# Leg 200: captured = False
# Leg at 200 translocating
# Leg 69: captured = False
# Leg at 69 translocating
# Leg 311: captured = False
# Leg at 311 translocating
# Leg 114: captured = False
# Leg at 114 translocating
# Leg 201: captured = False
# Leg at 201 translocating
# Leg 68: captured = False
# Leg at 68 translocating
# Leg 312: captured = False
# Leg at 312 translocating
# Leg 113: captured = False
# Leg at 113 translocating
# Leg 202: captured = False
# Leg at 202 translocating
# Leg 67: captured = False
# Leg at 67 translocating
# Leg 313: captured = False
# Leg at 313 translocating
# Leg 112: captured = False
# Leg at 112 translocating
# Leg 203: captured = False
# Leg at 203 translocating
# Leg 66: captured = False
# Leg at 66 translocating
# Leg 314: captured = False
# Leg at 314 translocating
# Leg 111: captured = False
# Leg at 111 translocating
# Leg 204: captured = False
# Leg at 204 translocating
# Leg 65: captured = False
# Leg at 65 translocating
# Leg 315: captured = False
# Leg at 315 translocating
# Leg 110: captured = False
# Leg at 110 translocating
# Leg 205: captured = False
# Leg at 205 translocating
# Leg 64: captured = False
# Leg at 64 translocating
# Leg 316: captured = False
# Leg at 316 translocating
# Leg 109: captured = False
# Leg at 109 translocating
# Leg 206: captured = False
# Leg at 206 translocating
# Leg 63: captured = False
# Leg at 63 translocating
# Leg 317: captured = False
# Leg at 317 translocating
# Leg 108: captured = False
# Leg at 108 translocating
# Leg 207: captured = False
# Leg at 207 translocating
# Leg 62: captured = False
# Leg at 62 translocating
# Leg 318: captured = False
# Leg at 318 translocating
# Leg 107: captured = False
# Leg at 107 translocating
# Leg 208: captured = False
# Leg at 208 translocating
# Leg 61: captured = False
# Leg at 61 translocating
# Leg 319: captured = False
# Leg at 319 translocating
# Leg 106: captured = False
# Leg at 106 translocating
# Leg 209: captured = False
# Leg at 209 translocating
# Leg 60: captured = False
# Leg at 60 translocating
# Leg 320: captured = False
# Leg at 320 translocating
# Leg 105: captured = False
# Leg at 105 translocating
# Leg 210: captured = False
# Leg at 210 translocating
# Leg 59: captured = False
# Leg at 59 translocating
# Leg 321: captured = False
# Leg at 321 translocating
# Leg 104: captured = False
# Leg at 104 translocating
# Leg 211: captured = False
# Leg at 211 translocating
# Leg 58: captured = False
# Leg at 58 translocating
# Leg 322: captured = False
# Leg at 322 translocating
# Leg 103: captured = False
# Leg at 103 translocating
# Leg 212: captured = False
# Leg at 212 translocating

# %%
with h5py.File("trajectory/LEFPositions.h5", mode='r') as f:
    pos = f['positions']
    print(pos[:,:,:])
# Out:
# [[[174 177]
#   [249 252]]
#
#  [[173 178]
#   [248 253]]
#
#  [[172 179]
#   [247 254]]
#
#  [[171 180]
#   [246 255]]
#
#  [[170 181]
#   [245 256]]
#
#  [[169 182]
#   [244 257]]
#
#  [[168 183]
#   [243 258]]
#
#  [[167 184]
#   [242 259]]
#
#  [[166 185]
#   [241 260]]
#
#  [[165 186]
#   [240 261]]
#
#  [[164 187]
#   [239 262]]
#
#  [[163 188]
#   [238 263]]
#
#  [[162 189]
#   [237 264]]
#
#  [[161 190]
#   [236 265]]
#
#  [[160 191]
#   [235 266]]
#
#  [[159 192]
#   [234 267]]
#
#  [[158 193]
#   [233 268]]
#
#  [[157 194]
#   [232 269]]
#
#  [[156 195]
#   [231 270]]
#
#  [[155 196]
#   [230 271]]
#
#  [[154 197]
#   [229 272]]
#
#  [[153 198]
#   [228 273]]
#
#  [[152 199]
#   [227 274]]
#
#  [[151 200]
#   [226 275]]
#
#  [[150 201]
#   [225 276]]
#
#  [[149 202]
#   [224 277]]
#
#  [[148 203]
#   [223 278]]
#
#  [[147 204]
#   [222 279]]
#
#  [[146 205]
#   [221 280]]
#
#  [[145 206]
#   [220 281]]
#
#  [[144 207]
#   [219 282]]
#
#  [[143 208]
#   [218 283]]
#
#  [[142 209]
#   [217 284]]
#
#  [[141 210]
#   [216 285]]
#
#  [[140 211]
#   [215 286]]
#
#  [[139 212]
#   [214 287]]
#
#  [[138 213]
#   [214 288]]
#
#  [[137 213]
#   [214 289]]
#
#  [[136 213]
#   [214 290]]
#
#  [[135 213]
#   [214 291]]
#
#  [[134 213]
#   [410 413]]
#
#  [[133 214]
#   [409 414]]
#
#  [[132 215]
#   [408 415]]
#
#  [[131 216]
#   [407 416]]
#
#  [[130 217]
#   [406 417]]
#
#  [[129 218]
#   [405 418]]
#
#  [[128 219]
#   [404 419]]
#
#  [[127 220]
#   [403 420]]
#
#  [[126 221]
#   [402 421]]
#
#  [[125 222]
#   [401 422]]
#
#  [[124 223]
#   [400 423]]
#
#  [[123 224]
#   [399 424]]
#
#  [[122 225]
#   [398 425]]
#
#  [[121 226]
#   [397 426]]
#
#  [[120 227]
#   [396 427]]
#
#  [[119 228]
#   [395 428]]
#
#  [[118 229]
#   [394 429]]
#
#  [[117 230]
#   [393 430]]
#
#  [[116 231]
#   [392 431]]
#
#  [[115 232]
#   [391 432]]
#
#  [[114 233]
#   [390 433]]
#
#  [[113 234]
#   [389 434]]
#
#  [[112 235]
#   [388 435]]
#
#  [[111 236]
#   [387 436]]
#
#  [[110 237]
#   [386 437]]
#
#  [[109 238]
#   [385 438]]
#
#  [[108 239]
#   [384 439]]
#
#  [[107 240]
#   [383 440]]
#
#  [[106 241]
#   [382 441]]
#
#  [[105 242]
#   [381 442]]
#
#  [[104 243]
#   [380 443]]
#
#  [[103 244]
#   [379 444]]
#
#  [[102 245]
#   [378 445]]
#
#  [[101 246]
#   [377 446]]
#
#  [[100 247]
#   [376 447]]
#
#  [[100 248]
#   [375 448]]
#
#  [[100 249]
#   [374 449]]
#
#  [[100 250]
#   [373 450]]
#
#  [[100 251]
#   [372 451]]
#
#  [[100 252]
#   [371 452]]
#
#  [[100 253]
#   [370 453]]
#
#  [[100 254]
#   [369 454]]
#
#  [[100 255]
#   [368 455]]
#
#  [[100 256]
#   [367 456]]
#
#  [[100 257]
#   [366 457]]
#
#  [[100 258]
#   [365 458]]
#
#  [[100 259]
#   [364 459]]
#
#  [[100 260]
#   [363 460]]
#
#  [[100 261]
#   [362 461]]
#
#  [[100 262]
#   [361 462]]
#
#  [[100 263]
#   [360 463]]
#
#  [[100 264]
#   [359 464]]
#
#  [[100 265]
#   [358 465]]
#
#  [[100 266]
#   [357 466]]
#
#  [[100 267]
#   [356 467]]
#
#  [[100 268]
#   [355 468]]
#
#  [[100 269]
#   [354 469]]
#
#  [[100 270]
#   [353 470]]
#
#  [[100 271]
#   [352 471]]
#
#  [[100 272]
#   [351 472]]
#
#  [[100 273]
#   [350 473]]
#
#  [[100 274]
#   [349 474]]
#
#  [[100 275]
#   [348 475]]
#
#  [[100 276]
#   [347 476]]
#
#  [[100 277]
#   [346 477]]
#
#  [[100 278]
#   [345 478]]
#
#  [[100 279]
#   [344 479]]
#
#  [[100 280]
#   [343 480]]
#
#  [[100 281]
#   [342 481]]
#
#  [[100 282]
#   [341 482]]
#
#  [[100 283]
#   [340 483]]
#
#  [[100 284]
#   [339 484]]
#
#  [[100 285]
#   [338 485]]
#
#  [[100 286]
#   [337 486]]
#
#  [[100 287]
#   [336 487]]
#
#  [[100 288]
#   [335 488]]
#
#  [[100 289]
#   [334 489]]
#
#  [[100 290]
#   [333 490]]
#
#  [[100 291]
#   [332 491]]
#
#  [[100 292]
#   [331 492]]
#
#  [[100 293]
#   [330 493]]
#
#  [[100 294]
#   [329 494]]
#
#  [[100 295]
#   [328 495]]
#
#  [[100 296]
#   [327 496]]
#
#  [[100 297]
#   [326 497]]
#
#  [[100 298]
#   [325 498]]
#
#  [[100 299]
#   [324 498]]
#
#  [[100 300]
#   [323 498]]
#
#  [[100 300]
#   [322 498]]
#
#  [[100 300]
#   [321 498]]
#
#  [[100 300]
#   [320 498]]
#
#  [[100 300]
#   [319 498]]
#
#  [[100 300]
#   [318 498]]
#
#  [[100 300]
#   [317 498]]
#
#  [[100 300]
#   [316 498]]
#
#  [[100 300]
#   [315 498]]
#
#  [[100 300]
#   [314 498]]
#
#  [[100 300]
#   [313 498]]
#
#  [[100 300]
#   [312 498]]
#
#  [[100 300]
#   [311 498]]
#
#  [[100 300]
#   [310 498]]
#
#  [[100 300]
#   [309 498]]
#
#  [[100 300]
#   [308 498]]
#
#  [[100 300]
#   [307 498]]
#
#  [[100 300]
#   [306 498]]
#
#  [[100 300]
#   [156 159]]
#
#  [[100 300]
#   [155 160]]
#
#  [[100 300]
#   [154 161]]
#
#  [[100 300]
#   [153 162]]
#
#  [[100 300]
#   [152 163]]
#
#  [[100 300]
#   [151 164]]
#
#  [[100 300]
#   [150 165]]
#
#  [[100 300]
#   [149 166]]
#
#  [[100 300]
#   [148 167]]
#
#  [[100 300]
#   [147 168]]
#
#  [[100 300]
#   [146 169]]
#
#  [[100 300]
#   [145 170]]
#
#  [[ 99 300]
#   [144 171]]
#
#  [[ 98 300]
#   [143 172]]
#
#  [[ 97 300]
#   [142 173]]
#
#  [[ 96 300]
#   [141 174]]
#
#  [[ 95 300]
#   [140 175]]
#
#  [[ 94 300]
#   [139 176]]
#
#  [[ 93 300]
#   [138 177]]
#
#  [[ 92 300]
#   [137 178]]
#
#  [[ 91 300]
#   [136 179]]
#
#  [[ 90 300]
#   [135 180]]
#
#  [[ 89 300]
#   [134 181]]
#
#  [[ 88 300]
#   [133 182]]
#
#  [[ 87 300]
#   [132 183]]
#
#  [[ 86 300]
#   [131 184]]
#
#  [[ 85 300]
#   [130 185]]
#
#  [[ 84 300]
#   [129 186]]
#
#  [[ 83 300]
#   [128 187]]
#
#  [[ 82 300]
#   [127 188]]
#
#  [[ 81 300]
#   [126 189]]
#
#  [[ 80 300]
#   [125 190]]
#
#  [[ 79 301]
#   [124 191]]
#
#  [[ 78 302]
#   [123 192]]
#
#  [[ 77 303]
#   [122 193]]
#
#  [[ 76 304]
#   [121 194]]
#
#  [[ 75 305]
#   [120 195]]
#
#  [[ 74 306]
#   [119 196]]
#
#  [[ 73 307]
#   [118 197]]
#
#  [[ 72 308]
#   [117 198]]
#
#  [[ 71 309]
#   [116 199]]
#
#  [[ 70 310]
#   [115 200]]
#
#  [[ 69 311]
#   [114 201]]
#
#  [[ 68 312]
#   [113 202]]
#
#  [[ 67 313]
#   [112 203]]
#
#  [[ 66 314]
#   [111 204]]
#
#  [[ 65 315]
#   [110 205]]
#
#  [[ 64 316]
#   [109 206]]
#
#  [[ 63 317]
#   [108 207]]
#
#  [[ 62 318]
#   [107 208]]
#
#  [[ 61 319]
#   [106 209]]
#
#  [[ 60 320]
#   [105 210]]
#
#  [[ 59 321]
#   [104 211]]
#
#  [[ 58 322]
#   [103 212]]
#
#  [[ 57 323]
#   [102 213]]]
